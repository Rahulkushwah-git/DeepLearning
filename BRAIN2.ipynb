# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder 
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
# Out:
# /Users/rahulkushwah/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]])
# Out:
# OneHotEncoder()

# %%
data = []
paths = []
result = []

for r, d, f in os.walk(r'/Users/rahulkushwah/Documents/JUPYTER/archive (1)/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((240,240))
    img = np.array(img)
    if(img.shape == (240,240,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
paths = []
for r, d, f in os.walk(r"/Users/rahulkushwah/Documents/JUPYTER/archive (1)/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((240,240))
    img = np.array(img)
    if(img.shape == (240,240,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (2891, 240, 240, 3)

# %%
result = np.array(result)
result = result.reshape(2891,2)

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
model = Sequential()

# Zero Padding Layer with pool size of (2,2)
model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(240, 240, 3), padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

# Convolution Layer with 32 filters, each of 7*7 pixels and stride equal to 1
model.add(Conv2D(32, kernel_size=(7, 7), strides=(1, 1), activation='relu', padding='valid'))

# Batch Normalization Layer with 32 filters
model.add(BatchNormalization())

# Activation Layer with ReLU activation function
model.add(Conv2D(32, kernel_size=(1, 1), activation='relu'))

# Pooling Layer 1 with pool size of (4,4)
model.add(MaxPooling2D(pool_size=(4, 4)))

# Pooling Layer 2 with pool size of (2,2)
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten Layer
model.add(Flatten())

# Densely Connected Layer with 512 neurons
model.add(Dense(512, activation='relu'))

# Output Layer with single neuron for tumor classification
model.add(Dense(2, activation='softmax'))

# Model Compilation
model.compile(loss="categorical_crossentropy", optimizer="Adamax", metrics=["accuracy"])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 240, 240, 32)      416
#
#  batch_normalization (Batch  (None, 240, 240, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 120, 120, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 114, 114, 32)      50208
#
#  batch_normalization_1 (Bat  (None, 114, 114, 32)      128
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 114, 114, 32)      1056
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 32)        0
#  g2D)
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3264738 (12.45 MB)
# Trainable params: 3264610 (12.45 MB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (2312, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 58/58 [==============================] - 73s 1s/step - loss: 2.8146 - accuracy: 0.6786 - val_loss: 0.6287 - val_accuracy: 0.7444
# Epoch 2/30
# 58/58 [==============================] - 76s 1s/step - loss: 0.4584 - accuracy: 0.7837 - val_loss: 0.6341 - val_accuracy: 0.7824
# Epoch 3/30
# 58/58 [==============================] - 79s 1s/step - loss: 0.4205 - accuracy: 0.8015 - val_loss: 0.5185 - val_accuracy: 0.8117
# Epoch 4/30
# 58/58 [==============================] - 80s 1s/step - loss: 0.3783 - accuracy: 0.8235 - val_loss: 0.4052 - val_accuracy: 0.8428
# Epoch 5/30
# 58/58 [==============================] - 81s 1s/step - loss: 0.3526 - accuracy: 0.8408 - val_loss: 0.3701 - val_accuracy: 0.8290
# Epoch 6/30
# 58/58 [==============================] - 82s 1s/step - loss: 0.3221 - accuracy: 0.8655 - val_loss: 0.3486 - val_accuracy: 0.8342
# Epoch 7/30
# 58/58 [==============================] - 83s 1s/step - loss: 0.3064 - accuracy: 0.8724 - val_loss: 0.3301 - val_accuracy: 0.8670
# Epoch 8/30
# 58/58 [==============================] - 93s 2s/step - loss: 0.2803 - accuracy: 0.8780 - val_loss: 0.3153 - val_accuracy: 0.8739
# Epoch 9/30
# 58/58 [==============================] - 87s 1s/step - loss: 0.2476 - accuracy: 0.8971 - val_loss: 0.2827 - val_accuracy: 0.8860
# Epoch 10/30
# 58/58 [==============================] - 88s 2s/step - loss: 0.2223 - accuracy: 0.9126 - val_loss: 0.2918 - val_accuracy: 0.8912
# Epoch 11/30
# 58/58 [==============================] - 87s 1s/step - loss: 0.1856 - accuracy: 0.9343 - val_loss: 0.2968 - val_accuracy: 0.8722
# Epoch 12/30
# 58/58 [==============================] - 87s 2s/step - loss: 0.1703 - accuracy: 0.9407 - val_loss: 0.2984 - val_accuracy: 0.8756
# Epoch 13/30
# 58/58 [==============================] - 87s 2s/step - loss: 0.1462 - accuracy: 0.9550 - val_loss: 0.2155 - val_accuracy: 0.9292
# Epoch 14/30
# 58/58 [==============================] - 88s 2s/step - loss: 0.1347 - accuracy: 0.9576 - val_loss: 0.2138 - val_accuracy: 0.9275
# Epoch 15/30
# 58/58 [==============================] - 89s 2s/step - loss: 0.1083 - accuracy: 0.9693 - val_loss: 0.1694 - val_accuracy: 0.9551
# Epoch 16/30
# 58/58 [==============================] - 89s 2s/step - loss: 0.0935 - accuracy: 0.9715 - val_loss: 0.1796 - val_accuracy: 0.9378
# Epoch 17/30
# 58/58 [==============================] - 100s 2s/step - loss: 0.1143 - accuracy: 0.9645 - val_loss: 0.1543 - val_accuracy: 0.9499
# Epoch 18/30
# 58/58 [==============================] - 91s 2s/step - loss: 0.0684 - accuracy: 0.9870 - val_loss: 0.1304 - val_accuracy: 0.9689
# Epoch 19/30
# 58/58 [==============================] - 89s 2s/step - loss: 0.0636 - accuracy: 0.9870 - val_loss: 0.1282 - val_accuracy: 0.9672
# Epoch 20/30
# 58/58 [==============================] - 89s 2s/step - loss: 0.0504 - accuracy: 0.9901 - val_loss: 0.1323 - val_accuracy: 0.9620
# Epoch 21/30
# 58/58 [==============================] - 93s 2s/step - loss: 0.0407 - accuracy: 0.9909 - val_loss: 0.1153 - val_accuracy: 0.9689
# Epoch 22/30
# 58/58 [==============================] - 89s 2s/step - loss: 0.0365 - accuracy: 0.9926 - val_loss: 0.1074 - val_accuracy: 0.9689
# Epoch 23/30
# 58/58 [==============================] - 90s 2s/step - loss: 0.0383 - accuracy: 0.9926 - val_loss: 0.1204 - val_accuracy: 0.9655
# Epoch 24/30
# 58/58 [==============================] - 90s 2s/step - loss: 0.0319 - accuracy: 0.9935 - val_loss: 0.1015 - val_accuracy: 0.9741
# Epoch 25/30
# 58/58 [==============================] - 93s 2s/step - loss: 0.0246 - accuracy: 0.9952 - val_loss: 0.1321 - val_accuracy: 0.9655
# Epoch 26/30
# 58/58 [==============================] - 93s 2s/step - loss: 0.0249 - accuracy: 0.9944 - val_loss: 0.0978 - val_accuracy: 0.9689
# Epoch 27/30
# 58/58 [==============================] - 91s 2s/step - loss: 0.0214 - accuracy: 0.9961 - val_loss: 0.1765 - val_accuracy: 0.9413
# Epoch 28/30
# 58/58 [==============================] - 92s 2s/step - loss: 0.0130 - accuracy: 0.9983 - val_loss: 0.1057 - val_accuracy: 0.9706
# Epoch 29/30
# 58/58 [==============================] - 93s 2s/step - loss: 0.0119 - accuracy: 0.9991 - val_loss: 0.1848 - val_accuracy: 0.9326
# Epoch 30/30
# 58/58 [==============================] - 92s 2s/step - loss: 0.0130 - accuracy: 0.9978 - val_loss: 0.0943 - val_accuracy: 0.9793

# %%
#trained model, 'x_test', 'y_test' are test data
evaluation_results = model.evaluate(x_test, y_test)

# 'evaluate' method returns a list of metrics, including accuracy
accuracy = evaluation_results[1]

print("Model Accuracy on Test Set: {:.2f}%".format(accuracy * 100))
# Out:
# 19/19 [==============================] - 4s 218ms/step - loss: 0.0943 - accuracy: 0.9793
# Model Accuracy on Test Set: 97.93%

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()
